# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, median_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

pd.set_option("display.max_columns", 200)

# %%
from IPython.core.pylabtools import figsize
figsize(12, 8)
sns.set()

# %%
df_enem_train = pd.read_csv('train.csv')
df_enem_test = pd.read_csv('test.csv')

# %%
df_enem_train.head(3)
# Out:
#    Unnamed: 0                              NU_INSCRICAO  NU_ANO  \
# 0           1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016
# 1           2  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016
# 2           3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016
#
#    CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                  4314902            Porto Alegre                43
# 1                  2304707                  Granja                23
# 2                  2304400               Fortaleza                23
#
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0               RS        24       M              0.0            1
# 1               CE        17       F              0.0            3
# 2               CE        21       F              0.0            3
#
#    TP_NACIONALIDADE  CO_MUNICIPIO_NASCIMENTO NO_MUNICIPIO_NASCIMENTO  \
# 0                 1                4314902.0            Porto Alegre
# ...

# %%
df_enem_test.head(3)
# Out:
#                                NU_INSCRICAO  CO_UF_RESIDENCIA  \
# 0  ba0cc30ba34e7a46764c09dfc38ed83d15828897                43
# 1  177f281c68fa032aedbd842a745da68490926cd2                15
# 2  6cf0d8b97597d7625cdedc7bdb6c0f052286c334                29
#
#   SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_COR_RACA  TP_NACIONALIDADE  \
# 0               RS        19       F            1                 1
# 1               PA        24       M            3                 2
# 2               BA        16       F            2                 1
#
#    TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  TP_ENSINO  \
# 0                1                3          1        NaN
# 1                1                4          1        NaN
# 2                3                0          1        NaN
#
#    TP_DEPENDENCIA_ADM_ESC  IN_BAIXA_VISAO  IN_CEGUEIRA  IN_SURDEZ  \
# 0                     NaN               0            0          0
# 1                     NaN               0            0          0
# ...

# %%
variaveis_selecionadas = ["NU_IDADE", "TP_ST_CONCLUSAO", "TP_ANO_CONCLUIU", "IN_TREINEIRO"]

# %%
df_enem_train_vars = df_enem_train[variaveis_selecionadas]

# %%
df_enem_train_vars
# Out:
#        NU_IDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  IN_TREINEIRO
# 0            24                1                4             0
# 1            17                2                0             0
# 2            21                3                0             0
# 3            25                1                9             0
# 4            28                1                4             0
# ...         ...              ...              ...           ...
# 13725        20                1                3             0
# 13726        33                1               10             0
# 13727        15                3                0             1
# 13728        36                4                0             0
# 13729        17                2                0             0
#
# [13730 rows x 4 columns]

# %%
df_enem_train_vars.isna().sum()
# Out:
# NU_IDADE           0
# TP_ST_CONCLUSAO    0
# TP_ANO_CONCLUIU    0
# IN_TREINEIRO       0
# dtype: int64

# %%
df_enem_train_vars.corr()
# Out:
#                  NU_IDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  IN_TREINEIRO
# NU_IDADE         1.000000        -0.253403         0.681435     -0.295091
# TP_ST_CONCLUSAO -0.253403         1.000000        -0.592834      0.533983
# TP_ANO_CONCLUIU  0.681435        -0.592834         1.000000     -0.257710
# IN_TREINEIRO    -0.295091         0.533983        -0.257710      1.000000

# %% [markdown]
# # Define dados de treino e validação

# %%
X_df_enem_train_vars = df_enem_train_vars.drop('IN_TREINEIRO', axis=1)
y_df_enem_train_vars = df_enem_train_vars['IN_TREINEIRO']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_df_enem_train_vars, y_df_enem_train_vars, test_size=0.3, random_state=42)

# %%
X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((9611, 3), (9611,), (4119, 3), (4119,))

# %%
y_valid
# Out:
# 12453    0
# 12095    0
# 1575     0
# 3651     0
# 586      0
#         ..
# 10659    0
# 1336     0
# 12381    0
# 12761    0
# 11756    0
# Name: IN_TREINEIRO, Length: 4119, dtype: int64

# %% [markdown]
# # Modelo: Regressão Linear Simples

# %%
reg_lin = LinearRegression()

# %%
model_reg_lin = reg_lin.fit(X_train,y_train)

# %%
IN_TREINEIRO_train = model_reg_lin.predict(X_valid)

# %%
model_reg_lin.score(X_train, y_train)
# Out:
# 0.3753020054947155

# %%
model_reg_lin.score(X_valid, y_valid)
# Out:
# 0.3801771034293183

# %%
#Transforma em apenas 0 ou 1
IN_TREINEIRO_train_predict[IN_TREINEIRO_train_predict < 0] = 0
IN_TREINEIRO_train_predict[IN_TREINEIRO_train_predict > 0] = 1

# %%
mean_squared_error(model_reg_lin.predict(X_valid), y_valid)
# Out:
# 0.07082755630811614

# %% [markdown]
# # Modelo Random Forest

# %%
forest_regressor = RandomForestRegressor(n_estimators=100, n_jobs=1, random_state=42)

# %%
model_forest_regressor = forest_regressor.fit(X_train, y_train)

# %%
model_forest_regressor.score(X_train, y_train)
# Out:
# 0.9780999706986676

# %%
mean_squared_error(model_forest_regressor.predict(X_valid), y_valid)
# Out:
# 0.002564263579271231

# %% [markdown]
# # Início dos dados de teste

# %%
X_test = df_enem_test[["NU_IDADE", "TP_ST_CONCLUSAO", "TP_ANO_CONCLUIU"]]

# %%
X_test
# Out:
#       NU_IDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU
# 0           19                1                3
# 1           24                1                4
# 2           16                3                0
# 3           17                2                0
# 4           19                1                1
# ...        ...              ...              ...
# 4565        17                2                0
# 4566        20                1                2
# 4567        22                1                5
# 4568        19                2                0
# 4569        33                1               10
#
# [4570 rows x 3 columns]

# %%
IN_TREINEIRO_TEST = forest_regressor.predict(X_test)

# %%
IN_TREINEIRO_TEST = pd.Series(IN_TREINEIRO_TEST, name='IN_TREINEIRO')

# %%
IN_TREINEIRO_TEST = IN_TREINEIRO_TEST.astype(int)

# %%
#Transforma em apenas 0 ou 1
IN_TREINEIRO_train_predict[IN_TREINEIRO_train_predict < 0] = 0
IN_TREINEIRO_train_predict[IN_TREINEIRO_train_predict > 0] = 1

# %% [markdown]
# # Cria o arquivo csv para envio

# %%
df_answer = pd.DataFrame()
df_answer['NU_INSCRICAO'] = df_enem_test['NU_INSCRICAO']
df_answer['IN_TREINEIRO'] = IN_TREINEIRO_TEST
df_answer.head()
# Out:
#                                NU_INSCRICAO  IN_TREINEIRO
# 0  ba0cc30ba34e7a46764c09dfc38ed83d15828897             0
# 1  177f281c68fa032aedbd842a745da68490926cd2             0
# 2  6cf0d8b97597d7625cdedc7bdb6c0f052286c334             1
# 3  5c356d810fa57671402502cd0933e5601a2ebf1e             0
# 4  df47c07bd881c2db3f38c6048bf77c132ad0ceb3             0

# %%
df_answer.to_csv('answer.csv', index=False)
