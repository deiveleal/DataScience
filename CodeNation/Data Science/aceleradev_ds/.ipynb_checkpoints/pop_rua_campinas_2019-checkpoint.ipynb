# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pop_rua_campinas = pd.read_csv("Contagem da População em Situação de Rua Campinas 2019 (respostas) - Respostas ao formulário 1.csv")

# %%
pop_rua_campinas.head(7)
# Out:
#   Carimbo de data/hora Região Local                  1. Nome 2. Nome Social  \
# 0                  NaN    NaN   NaN                      NaN            NaN
# 1  21/03/2019 19:51:54  Leste   Rua  Juliano da Silva Moraes            NaN
# 2  21/03/2019 19:55:57  Leste   Rua    Luiz Gustavo de Souza            NaN
# 3  21/03/2019 20:01:54  Leste   Rua   Nayanne de Jesus Nunes            NaN
# 4  21/03/2019 20:09:03  Leste   Rua             Cesar Lázaro            NaN
# 5  21/03/2019 20:12:37  Leste   Rua                       NR            NaN
# 6  21/03/2019 20:12:52  Leste   Rua   Antônio Fábio de Jesus            NaN
#
#    3. Gênero 4. De que cor, ou raça, você se considera?  \
# 0        NaN                                        NaN
# 1  Masculino                                      Parda
# 2  Masculino                                      Preta
# 3   Feminino                                      Parda
# 4  Masculino                                      Parda
# ...

# %%
pop_rua_campinas.isna().sum()
# Out:
# Carimbo de data/hora                            1
# Região                                         92
# Local                                         208
# 1. Nome                                         1
# 2. Nome Social                                848
# 3. Gênero                                      36
# 4. De que cor, ou raça, você se considera?     76
# 5. Nome da Mãe:                               174
# 6. Idade                                       51
# 7. Naturalidade                               112
# 8. Última cidade                              147
# 9. Tempo em Campinas                          136
# 10. Tempo de Rua                              135
# 11. Escolaridade                              127
# 12. Categorização                              57
# 13. Caracterização                            220
# 14. Tipo de Substância                        188
# 15. Documentação                              121
# 16. Tem Cadastro Único                        201
# ...
