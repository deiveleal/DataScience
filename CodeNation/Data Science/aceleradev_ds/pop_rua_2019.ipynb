# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pop_rua_campinas = pd.read_csv("Contagem da População em Situação de Rua Campinas 2019 (respostas) - Respostas ao formulário 1.csv")

# %%
pop_rua_campinas.head(7)
# Out:
#   Carimbo de data/hora Região Local                  1. Nome 2. Nome Social  \
# 0                  NaN    NaN   NaN                      NaN            NaN
# 1  21/03/2019 19:51:54  Leste   Rua  Juliano da Silva Moraes            NaN
# 2  21/03/2019 19:55:57  Leste   Rua    Luiz Gustavo de Souza            NaN
# 3  21/03/2019 20:01:54  Leste   Rua   Nayanne de Jesus Nunes            NaN
# 4  21/03/2019 20:09:03  Leste   Rua             Cesar Lázaro            NaN
# 5  21/03/2019 20:12:37  Leste   Rua                       NR            NaN
# 6  21/03/2019 20:12:52  Leste   Rua   Antônio Fábio de Jesus            NaN
#
#    3. Gênero 4. De que cor, ou raça, você se considera?  \
# 0        NaN                                        NaN
# 1  Masculino                                      Parda
# 2  Masculino                                      Preta
# 3   Feminino                                      Parda
# 4  Masculino                                      Parda
# ...

# %%
pop_rua_campinas.isna().sum()
# Out:
# Carimbo de data/hora                            1
# Região                                         92
# Local                                         208
# 1. Nome                                         1
# 2. Nome Social                                848
# 3. Gênero                                      36
# 4. De que cor, ou raça, você se considera?     76
# 5. Nome da Mãe:                               174
# 6. Idade                                       51
# 7. Naturalidade                               112
# 8. Última cidade                              147
# 9. Tempo em Campinas                          136
# 10. Tempo de Rua                              135
# 11. Escolaridade                              127
# 12. Categorização                              57
# 13. Caracterização                            220
# 14. Tipo de Substância                        188
# 15. Documentação                              121
# 16. Tem Cadastro Único                        201
# ...

# %%
pop_rua_campinas.shape
# Out:
# (897, 27)

# %%
pop_rua_campinas = pop_rua_campinas.drop(columns=['Unnamed: 24', 'Unnamed: 25', 'Endereço de e-mail'])

# %%
pop_rua_campinas = pop_rua_campinas.drop(0)

# %%
pop_rua_campinas.head(7)
# Out:
#   Carimbo de data/hora Região Local                  1. Nome 2. Nome Social  \
# 1  21/03/2019 19:51:54  Leste   Rua  Juliano da Silva Moraes            NaN
# 2  21/03/2019 19:55:57  Leste   Rua    Luiz Gustavo de Souza            NaN
# 3  21/03/2019 20:01:54  Leste   Rua   Nayanne de Jesus Nunes            NaN
# 4  21/03/2019 20:09:03  Leste   Rua             Cesar Lázaro            NaN
# 5  21/03/2019 20:12:37  Leste   Rua                       NR            NaN
# 6  21/03/2019 20:12:52  Leste   Rua   Antônio Fábio de Jesus            NaN
# 7  21/03/2019 20:16:36  Norte   Rua                       NR            NaN
#
#    3. Gênero 4. De que cor, ou raça, você se considera?  \
# 1  Masculino                                      Parda
# 2  Masculino                                      Preta
# 3   Feminino                                      Parda
# 4  Masculino                                      Parda
# 5  Masculino                                     Branca
# ...

# %%
pop_rua_campinas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 896 entries, 1 to 896
# Data columns (total 24 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Carimbo de data/hora                        896 non-null    object
#  1   Região                                      805 non-null    object
#  2   Local                                       689 non-null    object
#  3   1. Nome                                     896 non-null    object
#  4   2. Nome Social                              49 non-null     object
#  5   3. Gênero                                   861 non-null    object
#  6   4. De que cor, ou raça, você se considera?  821 non-null    object
#  7   5. Nome da Mãe:                             723 non-null    object
#  8   6. Idade                                    846 non-null    object
#  9   7. Naturalidade                             785 non-null    object
# ...

# %%
pop_rua_campinas.describe()
# Out:
#        Carimbo de data/hora Região Local 1. Nome 2. Nome Social  3. Gênero  \
# count                   896    805   689     896             49        861
# unique                  894      6    17     836             46          3
# top     29/05/2019 11:57:59  Leste   Rua      NR           Beto  Masculino
# freq                      2    412   407      46              2        699
#
#        4. De que cor, ou raça, você se considera?     5. Nome da Mãe:   \
# count                                         821                  723
# unique                                          6                  708
# top                                         Parda  Maria José da Silva
# freq                                          343                    5
#
#             6. Idade 7. Naturalidade  ... 12. Categorização  \
# count            846             785  ...               840
# unique             6               6  ...                30
# ...

# %%
pop_rua_campinas.isna().sum()
# Out:
# Carimbo de data/hora                            0
# Região                                         91
# Local                                         207
# 1. Nome                                         0
# 2. Nome Social                                847
# 3. Gênero                                      35
# 4. De que cor, ou raça, você se considera?     75
# 5. Nome da Mãe:                               173
# 6. Idade                                       50
# 7. Naturalidade                               111
# 8. Última cidade                              146
# 9. Tempo em Campinas                          135
# 10. Tempo de Rua                              134
# 11. Escolaridade                              126
# 12. Categorização                              56
# 13. Caracterização                            219
# 14. Tipo de Substância                        187
# 15. Documentação                              120
# 16. Tem Cadastro Único                        200
# ...

# %%
pop_rua_campinas_naturalidade = pop_rua_campinas['12. Categorização']

# %%
sns.distplot(pop_rua_campinas_naturalidade.value_counts())
plt.show()

# %%
pop_rua_campinas.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pop_rua_campinas.to_csv('pop_rua_campinas_2019.csv')

# %%
pop_rua_campinas.columns
# Out:
# Index(['Carimbo de data/hora', 'Região', 'Local', '1. Nome', '2. Nome Social',
#        '3. Gênero', '4. De que cor, ou raça, você se considera?',
#        '5. Nome da Mãe: ', '6. Idade', '7. Naturalidade', '8. Última cidade',
#        '9. Tempo em Campinas', '10. Tempo de Rua', '11. Escolaridade',
#        '12. Categorização', '13. Caracterização', '14. Tipo de Substância',
#        '15. Documentação', '16. Tem Cadastro Único',
#        '17. Benefício Sócio-assistencial', '18. Benefícios Previdenciários',
#        'Entrevistador', 'Local da Entrevista', 'Observações'],
#       dtype='object')

# %%
pop_rua_campinas.shape
# Out:
# (896, 24)

# %%
pop_rua_campinas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 896 entries, 1 to 896
# Data columns (total 24 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Carimbo de data/hora                        896 non-null    object
#  1   Região                                      805 non-null    object
#  2   Local                                       689 non-null    object
#  3   1. Nome                                     896 non-null    object
#  4   2. Nome Social                              49 non-null     object
#  5   3. Gênero                                   861 non-null    object
#  6   4. De que cor, ou raça, você se considera?  821 non-null    object
#  7   5. Nome da Mãe:                             723 non-null    object
#  8   6. Idade                                    846 non-null    object
#  9   7. Naturalidade                             785 non-null    object
# ...

# %%
pop_rua_campinas.head(3)
# Out:
#   Carimbo de data/hora Região Local                  1. Nome 2. Nome Social  \
# 1  21/03/2019 19:51:54  Leste   Rua  Juliano da Silva Moraes            NaN
# 2  21/03/2019 19:55:57  Leste   Rua    Luiz Gustavo de Souza            NaN
# 3  21/03/2019 20:01:54  Leste   Rua   Nayanne de Jesus Nunes            NaN
#
#    3. Gênero 4. De que cor, ou raça, você se considera?  \
# 1  Masculino                                      Parda
# 2  Masculino                                      Preta
# 3   Feminino                                      Parda
#
#            5. Nome da Mãe:       6. Idade      7. Naturalidade  ...  \
# 1            Luiza da Silva  25 à 39 anos  Estado de São Paulo  ...
# 2  Lucia Aparecida de Souza  25 à 39 anos             Campinas  ...
# 3   Adelaide de Jesus Nunes  25 à 39 anos         Outro Estado  ...
#
#   12. Categorização                13. Caracterização 14. Tipo de Substância  \
# 1    Morador de Rua                               NaN         Álcool, Tabaco
# ...

# %%
pop_rua_campinas_idade = pop_rua_campinas[:]
pop_rua_campinas_idade.head(3)
# Out:
#   Carimbo de data/hora Região Local                  1. Nome 2. Nome Social  \
# 1  21/03/2019 19:51:54  Leste   Rua  Juliano da Silva Moraes            NaN
# 2  21/03/2019 19:55:57  Leste   Rua    Luiz Gustavo de Souza            NaN
# 3  21/03/2019 20:01:54  Leste   Rua   Nayanne de Jesus Nunes            NaN
#
#    3. Gênero 4. De que cor, ou raça, você se considera?  \
# 1  Masculino                                      Parda
# 2  Masculino                                      Preta
# 3   Feminino                                      Parda
#
#            5. Nome da Mãe:       6. Idade      7. Naturalidade  ...  \
# 1            Luiza da Silva  25 à 39 anos  Estado de São Paulo  ...
# 2  Lucia Aparecida de Souza  25 à 39 anos             Campinas  ...
# 3   Adelaide de Jesus Nunes  25 à 39 anos         Outro Estado  ...
#
#   12. Categorização                13. Caracterização 14. Tipo de Substância  \
# 1    Morador de Rua                               NaN         Álcool, Tabaco
# ...

# %%
sns.distplot(pop_rua_campinas_idade['6. Idade'].isna().sum())
# Out:
# /home/deive/Anaconda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.distplot(pop_rua_campinas_idade.count(pop_rua_campinas_idade['6. Idade']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-32dc268e06ea> in <module>
# ----> 1 sns.distplot(pop_rua_campinas_idade.count(pop_rua_campinas_idade['6. Idade']))
#
# ~/Anaconda/lib/python3.7/site-packages/pandas/core/frame.py in count(self, axis, level, numeric_only)
#    7782         Myla      1
#    7783         """
# -> 7784         axis = self._get_axis_number(axis)
#    7785         if level is not None:
#    7786             return self._count_level(level, axis=axis, numeric_only=numeric_only)
#
# ~/Anaconda/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     396     @classmethod
#     397     def _get_axis_number(cls, axis):
# --> 398         axis = cls._AXIS_ALIASES.get(axis, axis)
#     399         if is_integer(axis):
#     400             if axis in cls._AXIS_NAMES:
#
# ...
